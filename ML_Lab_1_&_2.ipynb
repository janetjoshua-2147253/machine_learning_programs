# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/ML LAB/amazon_prime_titles - amazon_prime_titles.csv")
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
df.describe()
# Out:
#        release_year
# count   9668.000000
# mean    2008.341849
# std       18.922482
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df = df.drop_duplicates(["title"])
print("Duplicates removed")
# Out:
# Duplicates removed

# %%
df=df.reset_index()
df.head()
# Out:
#    index show_id   type                 title        director  \
# 0      0      s1  Movie   The Grand Seduction    Don McKellar
# 1      1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      2      s3  Movie  Secrets of Deception     Josh Webber
# 3      3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
df["rating"].unique()
# Out:
# array(['13+', 'ALL', '18+', 'R', 'TV-Y', 'TV-Y7', 'NR', '16+', 'TV-PG',
#        '7+', 'TV-14', 'TV-NR', 'TV-G', 'PG-13', 'TV-MA', 'G', 'PG',
#        'NC-17', 'UNRATED', '16', 'AGES_16_', 'AGES_18_', 'ALL_AGES',
#        'NOT_RATE'], dtype=object)

# %%
small = df.sort_values("release_year", ascending = True)
small = small[small['duration'] != ""]
small[['title', "release_year"]][:15]
# Out:
#                                                   title  release_year
# 83                                     Within Our Gates          1920
# 1284                                          Pollyanna          1920
# 1474                                Nomads Of The North          1920
# 1143                                Robin Hood (Silent)          1922
# 1425                                 One Exciting Night          1922
# 1684                                     Merry-Go-Round          1923
# 1134                                             Romola          1924
# 8590                                        Tumbleweeds          1925
# 2629                       Don Q, Son of Zorro (Silent)          1925
# 6627            Sir Arthur Conan Doyle's The Lost World          1925
# 685                               The Eagle (No Dialog)          1925
# 1776                                      Madame Behave          1925
# ...

# %%
#Boxplot

release_year = df["release_year"]
type = df["type"]
sns.boxplot(x=release_year, y=type)
plt.show()

# %%
#Rename()

import os
import datetime

Current_Date = datetime.datetime.today().strftime ('%d-%b-%Y')
os.rename(r'/content/drive/MyDrive/ML LAB/amazon_prime_titles.csv',r'/content/drive/MyDrive/ML LAB/dataset_amazon_prime_titles.csv')

# %%
#Groupby() 
ry = df.groupby('type')
ry.first()

ry.get_group('TV Show')
# Out:
#      show_id     type                          title director  \
# 17       s18  TV Show                     Zoo Babies      NaN
# 18       s19  TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# 20       s21  TV Show                     Zoboomafoo      NaN
# 21       s22  TV Show      Zo Zo Zombie: Mini-Series      NaN
# 23       s24  TV Show                   ZeroZeroZero      NaN
# ...      ...      ...                            ...      ...
# 9651   s9652  TV Show                     Glass Room      NaN
# 9655   s9656  TV Show          DaFUNdamentals Series      NaN
# 9661   s9662  TV Show                     Terrahawks      NaN
# 9664   s9665  TV Show                  Planet Patrol      NaN
# 9666   s9667  TV Show        Maradona: Blessed Dream      NaN
#
#                                                    cast country date_added  \
# 17                           Narrator - Gillian Barlett     NaN        NaN
# ...

# %%
# Bar()

plt.figure(figsize=(10,6))
df["rating"].value_counts(normalize =True).plot(kind="bar", color = "orange")
plt.xlabel("Ratings category")
plt.ylabel("Frequency distribution")
# Out:
# Text(0, 0.5, 'Frequency distribution')

# %%
# Barh()

h=df.head(30)
type=h['duration']
country=h['release_year']
plt.barh(type,country)
plt.show()

# %%
# Histplot()

type=df['release_year']
plt.hist(type)
plt.show()

# %%
# Pairplot()

sns.pairplot(data=df)

# %%
# Distplot()
h=df.head(9000)
year=h['release_year']
sns.displot(year)
plt.show()

# %%
# Jointplot()

h=df.head(20)
cn = h['country']
date_added = h['date_added']
sns.jointplot(x=cn, y=date_added)
plt.show()

# %%
# Stripplot()

h=df.head(9000)
ss=h['type']
content = h['release_year']
sns.stripplot(x=ss,y=content)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Violinplot()

h=df.head(10)
da = h['release_year']
sns.violinplot(da)
plt.show()

# %%
# Distplot()


sns.heatmap(df.corr(), center=0, cmap='PiYG')
plt.show()

# %%
# Scatter()

h=df.head(30)
release_year = h["release_year"]
type = h["listed_in"]
plt.scatter(release_year, type)
plt.show()

# %%
# Pie()

import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot

col = "type"
grouped = df[col].value_counts().reset_index()
grouped = grouped.rename(columns = {col : "count", "index" : col})

trace = go.Pie(labels=grouped[col], values=grouped['count'], pull=[0.05, 0], marker=dict(colors=["#6ad49b", "#a678de"]))
layout = go.Layout(title="", height=400, legend=dict(x=0.1, y=1.1))
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Corr()

df.corr(method ='kendall')
# Out:
#               release_year
# release_year           1.0
